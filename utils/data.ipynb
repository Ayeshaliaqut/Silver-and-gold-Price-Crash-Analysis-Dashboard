# %%
import pandas as pd
df = pd.read_csv(r"E:\internship\data\gld_price_data.csv")
print(df.head())
# Out:
#        Date          SPX        GLD        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3  1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4  1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
df = df[["Date", "GLD", "SLV"]]
df = df.dropna()
print(df)
# Out:
#            Date         GLD      SLV
# 0      1/2/2008   84.860001  15.1800
# 1      1/3/2008   85.570000  15.2850
# 2      1/4/2008   85.129997  15.1670
# 3      1/7/2008   84.769997  15.0530
# 4      1/8/2008   86.779999  15.5900
# ...         ...         ...      ...
# 2285   5/8/2018  124.589996  15.5100
# 2286   5/9/2018  124.330002  15.5300
# 2287  5/10/2018  125.180000  15.7400
# 2288  5/14/2018  124.489998  15.5600
# 2289  5/16/2018  122.543800  15.4542
#
# [2290 rows x 3 columns]
